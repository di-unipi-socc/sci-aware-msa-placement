# %%
from pathlib import Path
import pandas as pd

# Load the data
EXP_NAME = "exp-4"
base_path = Path(f"../parquets/{EXP_NAME}")

df_path = base_path / "raw-sci-aware.parquet"
df = pd.read_parquet(df_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <frozen importlib._bootstrap_external>:1489, in _path_importer_cache(cls, path)
#
# KeyError: '/home/massa/sci-aware-msa-placement/.venv/lib/python3.12/site-packages/pandas/compat/numpy'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pathlib import Path
# ----> 2 import pandas as pd
#       4 # Load the data
#       5 EXP_NAME = "exp-4"
#
# File ~/sci-aware-msa-placement/.venv/lib/python3.12/site-packages/pandas/__init__.py:46
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
# ...

# %%
# count how many cols starts with placement/
placement_cols = [col for col in df.columns if col.startswith("placement")]
# delete all cols that starts with placement/
config_cols = [col for col in df.columns if col.startswith("config/experiment/")]
# rename "base" to "exhaustive" in the heuristic column
df["heuristic"] = df["heuristic"].replace({"base": "exhaustive"})
df = df.drop(columns=placement_cols)
df = df.drop(columns=config_cols)
df.set_index("trial_id", inplace=True)
df
# Out:
#                  application     mode          heuristic    seed     size  \
# trial_id
# 3cf12_00000             demo   random          greenonly  123457       32
# 3cf12_00001             demo   random       capacityonly  123457       32
# 3cf12_00002             demo   random  linearcombination  123457       32
# 3cf12_00003             demo   random         exhaustive  123457       32
# 3cf12_00004             demo   random          greenonly  123457       64
# ...                      ...      ...                ...     ...      ...
# 3cf12_02555  online-boutique  curated         exhaustive  698087   524288
# 3cf12_02556  online-boutique  curated          greenonly  698087  1048576
# 3cf12_02557  online-boutique  curated       capacityonly  698087  1048576
# 3cf12_02558  online-boutique  curated  linearcombination  698087  1048576
# 3cf12_02559  online-boutique  curated         exhaustive  698087  1048576
#
# ...

# %%
df.to_parquet(base_path / "clean-sci-aware.parquet")
